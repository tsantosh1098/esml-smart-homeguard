# %%
import tqdm
import random
import pathlib
import itertools
import collections

import os
import cv2
import numpy as np
# import remotezip as rz

import tensorflow as tf

# Some modules to display an animation using imageio.
import imageio
from IPython import display
from urllib import request
# from tensorflow_docs.vis import embed

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
import os
import shutil

# Define the source directory containing subdirectories with videos
source_directory = "./datasets/base_dataset/anomaly_data"

# Define the destination directory where all videos will be moved
destination_directory = "./datasets/base_dataset/aaa"

# List of video file extensions to consider (you can extend this list)
video_extensions = (".mp4")

def move_videos_to_destination(source, destination):
    for root, dirs, files in os.walk(source):
        for file in files:
            if file.endswith(video_extensions):
                video_path = os.path.join(root, file)
                destination_path = os.path.join(destination, file)
                
                # Check if the destination file already exists, and rename if necessary
                if os.path.exists(destination_path):
                    filename, file_extension = os.path.splitext(file)
                    i = 1
                    while os.path.exists(destination_path):
                        destination_path = os.path.join(destination, f"{filename}_{i}{file_extension}")
                        i += 1
                
                shutil.move(video_path, destination_path)
                print(f"Moved: {video_path} to {destination_path}")

if not os.path.exists(destination_directory):
    os.makedirs(destination_directory)

# move_videos_to_destination(source_directory, destination_directory)
# Out:
# Moved: ./datasets/base_dataset/anomaly_data/murdering_shooting/uccrime_Shooting044_x264.mp4 to ./datasets/base_dataset/aaa/uccrime_Shooting044_x264.mp4
# Moved: ./datasets/base_dataset/anomaly_data/murdering_shooting/Shooting037_x264.mp4 to ./datasets/base_dataset/aaa/Shooting037_x264.mp4
# Moved: ./datasets/base_dataset/anomaly_data/murdering_shooting/Shooting002_x264.mp4 to ./datasets/base_dataset/aaa/Shooting002_x264.mp4
# Moved: ./datasets/base_dataset/anomaly_data/murdering_shooting/uccrime_Shooting036_x264.mp4 to ./datasets/base_dataset/aaa/uccrime_Shooting036_x264.mp4
# Moved: ./datasets/base_dataset/anomaly_data/murdering_shooting/Shooting005_x264.mp4 to ./datasets/base_dataset/aaa/Shooting005_x264.mp4
# Moved: ./datasets/base_dataset/anomaly_data/murdering_shooting/uccrime_Shooting040_x264.mp4 to ./datasets/base_dataset/aaa/uccrime_Shooting040_x264.mp4
# ...

# %%
import os
import shutil

# Define the source directory containing subdirectories with videos
source_directory = "./datasets/base_dataset/normal_data"

# Define the destination directory where all videos will be moved
destination_directory = "./datasets/base_dataset/aaa"

# List of video file extensions to consider (you can extend this list)
video_extensions = (".mp4")

def move_videos_to_destination(source, destination):
    for root, dirs, files in os.walk(source):
        for file in files:
            if file.endswith(video_extensions):
                video_path = os.path.join(root, file)
                destination_path = os.path.join(destination, file)
                
                # Check if the destination file already exists, and rename if necessary
                if os.path.exists(destination_path):
                    filename, file_extension = os.path.splitext(file)
                    i = 1
                    while os.path.exists(destination_path):
                        destination_path = os.path.join(destination, f"{filename}_{i}{file_extension}")
                        i += 1
                
                shutil.move(video_path, destination_path)
                print(f"Moved: {video_path} to {destination_path}")

if not os.path.exists(destination_directory):
    os.makedirs(destination_directory)

# move_videos_to_destination(source_directory, destination_directory)
# Out:
# Moved: ./datasets/base_dataset/normal_data/neutral/okutama_1.1.6_Standing_6.mp4 to ./datasets/base_dataset/aaa/okutama_1.1.6_Standing_6.mp4
# Moved: ./datasets/base_dataset/normal_data/neutral/N_232_0_0_1_0.mp4 to ./datasets/base_dataset/aaa/N_232_0_0_1_0.mp4
# Moved: ./datasets/base_dataset/normal_data/neutral/okutama_2.1.10_Standing_119.mp4 to ./datasets/base_dataset/aaa/okutama_2.1.10_Standing_119.mp4
# Moved: ./datasets/base_dataset/normal_data/neutral/caviar_Browse3.mp4 to ./datasets/base_dataset/aaa/caviar_Browse3.mp4
# Moved: ./datasets/base_dataset/normal_data/neutral/bitint_hug_0025.mp4 to ./datasets/base_dataset/aaa/bitint_hug_0025.mp4
# Moved: ./datasets/base_dataset/normal_data/neutral/N_248_0_0_1_0.mp4 to ./datasets/base_dataset/aaa/N_248_0_0_1_0.mp4
# Moved: ./datasets/base_dataset/normal_data/neutral/N_107_1_0_1_1.mp4 to ./datasets/base_dataset/aaa/N_107_1_0_1_1.mp4
# ...

# %%
def get_class(main_path):
    """ Retrieve the name of the class given a filename.

    Args:
      fname: get the mian dataset path

    Returns:
      return list of all classes
    """
    return os.listdir(main_path)

# %%
def get_files_per_class(main_path):
    """ Retrieve the files that belong to each class.

    Args:
      files: get the main data path.

    Returns:
      Dictionary of class names (key) and files (values). 
    """
    files_for_class = collections.defaultdict(list)
    classes = get_class(main_path)
    for class_name in classes:
        for fname in os.listdir(os.path.join(main_path, class_name)):
            files_for_class[class_name].append(os.path.join(main_path, class_name, fname))
    
    return files_for_class

# %%
NUM_CLASSES = 2
FILES_PER_CLASS = 1000

# %%
main_path = "./datasets/base_dataset"
files_for_class = get_files_per_class(main_path)
classes = list(files_for_class.keys())

# %%
print('Num classes:', len(classes))
print('Num videos for class[0]:', len(files_for_class[classes[0]]))
# Out:
# Num classes: 2
# Num videos for class[0]: 1208

# %%
## Create a new function called select_subset_of_classes that selects a subset of the classes present within the dataset and a particular number of files per class:


def select_subset_of_classes(files_for_class, classes, files_per_class):
    """ Create a dictionary with the class name and a subset of the files in that class.

    Args:
      files_for_class: Dictionary of class names (key) and files (values).
      classes: List of classes.
      files_per_class: Number of files per class of interest.

    Returns:
      Dictionary with class as key and list of specified number of video files in that class.
    """
    files_subset = dict()

    for class_name in classes:
        class_files = files_for_class[class_name]
        files_subset[class_name] = class_files[:files_per_class]

    return files_subset

# %%
files_subset = select_subset_of_classes(files_for_class, classes[:NUM_CLASSES], FILES_PER_CLASS)
list(files_subset.keys())
# Out:
# ['anomaly_data', 'normal_data']

# %%
## get back all the data into one folder

# main_path = "./datasets/base_dataset"
# for cls in classes:
#     sub_main_path = os.path.join(main_path, cls)
#     for sub_folder in ['train', 'test', 'val']:
#         dst_path = sub_main_path
#         for file in os.listdir(os.path.join(sub_main_path, sub_folder)):
#             src_path = os.path.join(sub_main_path, sub_folder, file)
#             shutil.move(src_path, dst_path)

# %%
### Define helper functions that split the videos into training, validation, and test sets.

def split_train_test_val(classes, files_for_class, main_path, splits):
    """ split the data into various parts, such as training, validation, and test.

    Args:
      zip_url: A URL with a ZIP file with the data.
      num_classes: Number of labels.
      splits: Dictionary specifying the training, validation, test, etc. (key) division of data 
              (value is number of files per split).
      download_dir: Directory to download data to.

    Return:
      Mapping of the directories containing the subsections of data.
    """

    for cls in classes:
        random.shuffle(files_for_class[cls])

    # Only use the number of classes you want in the dictionary
    files_for_class = {x: files_for_class[x] for x in classes}

    dirs = {'train': [], 'test': [], 'val': []}
    
    select_idx = 0
    for split_name, split_count in splits.items():
        dst_path = os.path.join(main_path, split_name)
        print(dst_path)
        if not os.path.exists(dst_path):
            os.makedirs(dst_path)
            print(f"Folder created.")
        else:
            print(f"Folder already exists.")
    
        for cls in classes:
            destination_path = os.path.join(dst_path, cls)
            print(destination_path)
            if not os.path.exists(destination_path):
                os.makedirs(destination_path)
                print(f"Folder created.")
            else:
                print(f"Folder already exists.")

            for idx in range(split_count):
                current_idx = select_idx + idx
                file_name = files_for_class[cls][current_idx].split('/')[-1]
                shutil.move(files_for_class[cls][current_idx], os.path.join(destination_path, file_name))
                dirs[split_name].append(os.path.join(destination_path, file_name))
        select_idx += split_count

    return dirs

# %%
main_path = "./datasets/base_dataset"
subset_paths = split_train_test_val(classes, files_for_class, main_path, splits = {"train": 700, "val": 150, "test": 150})
# Out:
# ./datasets/base_dataset/train
# Folder created.
# ./datasets/base_dataset/train/anomaly_data
# Folder created.
# ./datasets/base_dataset/train/normal_data
# Folder created.
# ./datasets/base_dataset/val
# Folder created.
# ./datasets/base_dataset/val/anomaly_data
# Folder created.
# ./datasets/base_dataset/val/normal_data
# Folder created.
# ./datasets/base_dataset/test
# Folder created.
# ./datasets/base_dataset/test/anomaly_data
# Folder created.
# ./datasets/base_dataset/test/normal_data
# Folder created.

# %%
custom_subset_paths = subset_paths.copy()

# %%
# for key in subset_paths.keys():
    # print(subset_paths[key])

# %%
mainPath = pathlib.Path(main_path)
video_count_train = len(list(mainPath.glob('train/*/*.mp4')))
video_count_val = len(list(mainPath.glob('val/*/*.mp4')))
video_count_test = len(list(mainPath.glob('test/*/*.mp4')))
video_total = video_count_train + video_count_val + video_count_test
print(f"Total videos: {video_total}")
# Out:
# Total videos: 2000

# %%
# !find ./datasets/base_dataset
# Out:
# ./datasets/base_dataset
# ./datasets/base_dataset/test
# ./datasets/base_dataset/test/anomaly_data
# ./datasets/base_dataset/test/anomaly_data/okutama_2.2.10_Lying_58.mp4
# ./datasets/base_dataset/test/anomaly_data/ucarg_person05_02_aerial_throwing.mp4
# ./datasets/base_dataset/test/anomaly_data/ucarg_person04_01_aerial_boxing.mp4
# ./datasets/base_dataset/test/anomaly_data/Fighting038_x264.mp4
# ./datasets/base_dataset/test/anomaly_data/Shooting002_x264.mp4
# ./datasets/base_dataset/test/anomaly_data/Stealing066_x264.mp4
# ./datasets/base_dataset/test/anomaly_data/uccrime_Burglary055_x264.mp4
# ./datasets/base_dataset/test/anomaly_data/bitint_box_0037.mp4
# ./datasets/base_dataset/test/anomaly_data/ucarg_person12_04_rooftop_throwing.mp4
# ./datasets/base_dataset/test/anomaly_data/okutama_1.1.7_Lying_29.mp4
# ./datasets/base_dataset/test/anomaly_data/F_105_1_0_0_0.mp4
# ./datasets/base_dataset/test/anomaly_data/ucarg_person02_02_ground_throwing.mp4
# ...

# %% [markdown]
# ### Create frames from each video file

# %%
# def format_frames(frame, output_size):
#     """
#     Pad and resize an image from a video.

#     Args:
#       frame: Image that needs to resized and padded. 
#       output_size: Pixel size of the output frame image.

#     Return:
#       Formatted frame with padding of specified output size.
#     """
#     frame = tf.image.convert_image_dtype(frame, tf.float32)
#     frame = tf.image.resize_with_pad(frame, *output_size)
#     return frame

# %%
def format_frames(frame, output_size):
    """
    Pad and resize an image from a video.

    Args:
      frame: Image that needs to resized and padded. 
      output_size: Pixel size of the output frame image.

    Return:
      Formatted frame with padding of specified output size.
    """
    try:
        frame = tf.image.convert_image_dtype(frame, tf.float32)
        frame = tf.image.resize_with_pad(frame, *output_size)
        return frame
        
    except tf.errors.InvalidArgumentError as e:
        # Handle the specific exception raised when the conversion fails
        print(f"Error converting image data type: {e}")
        # You may want to log the error, raise a custom exception, or take other actions
    except Exception as e:
        # Handle other exceptions that might occur
        print(f"An unexpected error occurred: {e}")
        # You can customize this block based on your specific needs

# %%
def frames_from_video_file(video_path, n_frames, output_size = (224,224), frame_step = 5):
    """
    Creates frames from each video file present for each category.

    Args:
      video_path: File path to the video.
      n_frames: Number of frames to be created per video file.
      output_size: Pixel size of the output frame image.

    Return:
      An NumPy array of frames in the shape of (n_frames, height, width, channels).
    """
    # Read each video frame by frame
    result = []
    src = cv2.VideoCapture(str(video_path))  

    video_length = src.get(cv2.CAP_PROP_FRAME_COUNT)

    need_length = 1 + (n_frames - 1) * frame_step

    if need_length > video_length:
        start = 0
    else:
        max_start = video_length - need_length
        start = random.randint(0, max_start + 1)

    src.set(cv2.CAP_PROP_POS_FRAMES, start)
    # ret is a boolean indicating whether read was successful, frame is the image itself
    ret, frame = src.read()
    result.append(format_frames(frame, output_size))

    for _ in range(n_frames - 1):
        for _ in range(frame_step):
            ret, frame = src.read()
        if ret:
            frame = format_frames(frame, output_size)
            result.append(frame)
        else:
            result.append(np.zeros_like(result[0]))
    src.release()
    result = np.array(result)[..., [2, 1, 0]]

    return result

# %%
# main_path

idx = 0
for sub_folder in ['train', 'test', 'val']:
    sub_folder_path = os.path.join(main_path, sub_folder)
    for sub_sub_folder in os.listdir(sub_folder_path):
        sub_sub_folder_path = os.path.join(sub_folder_path, sub_sub_folder)
        video_path = sub_sub_folder_path
        for file in os.listdir(sub_sub_folder_path):
            video_path = os.path.join(sub_sub_folder_path, file)
            sample_video = frames_from_video_file(video_path, n_frames = 60)
            print("#######", idx, video_path, sample_video.shape)
            idx += 1
# Out:
# ####### 0 ./datasets/base_dataset/train/anomaly_data/bitint_push_0036.mp4 (60, 224, 224, 3)
# ####### 1 ./datasets/base_dataset/train/anomaly_data/Stealing049_x264.mp4 (60, 224, 224, 3)
# ####### 2 ./datasets/base_dataset/train/anomaly_data/utint_33_16_punch.mp4 (60, 224, 224, 3)
# ####### 3 ./datasets/base_dataset/train/anomaly_data/uccrime_Burglary073_x264.mp4 (60, 224, 224, 3)
# ####### 4 ./datasets/base_dataset/train/anomaly_data/bitint_box_0017.mp4 (60, 224, 224, 3)
# ####### 5 ./datasets/base_dataset/train/anomaly_data/Stealing098_x264.mp4 (60, 224, 224, 3)
# ####### 6 ./datasets/base_dataset/train/anomaly_data/ucarg_person04_04_aerial_boxing.mp4 (60, 224, 224, 3)
# ####### 7 ./datasets/base_dataset/train/anomaly_data/F_80_1_2_0_0.mp4 (60, 224, 224, 3)
# ####### 8 ./datasets/base_dataset/train/anomaly_data/okutama_1.2.10_Lying_38.mp4 (60, 224, 224, 3)
# ####### 9 ./datasets/base_dataset/train/anomaly_data/utint_0_11_punch.mp4 (60, 224, 224, 3)
# ...

# %%
# def to_gif(images):
#     converted_images = np.clip(images * 255, 0, 255).astype(np.uint8)
#     imageio.mimsave('./animation.gif', converted_images, fps=10)
#     return embed.embed_file('./animation.gif')

# %%
# to_gif(sample_video)

# %% [markdown]
# #### Next, define the FrameGenerator class in order to create an iterable object that can feed data into the TensorFlow data pipeline. The generator (__call__) function yields the frame array produced by frames_from_video_file and a one-hot encoded vector of the label associated with the set of frames.

# %%
class FrameGenerator:
    def __init__(self, path, n_frames, training = False):
        """ Returns a set of frames with their associated label. 

          Args:
            path: Video file paths.
            n_frames: Number of frames. 
            training: Boolean to determine if training dataset is being created.
        """
        print("path", path)
        self.path = path
        self.n_frames = n_frames
        self.training = training
        self.class_names = sorted(set(p.name for p in self.path.iterdir() if p.is_dir()))
        self.class_ids_for_name = dict((name, idx) for idx, name in enumerate(self.class_names))

    def get_files_and_class_names(self):
        video_paths = list(self.path.glob('*/*.mp4'))
        classes = [p.parent.name for p in video_paths] 
        return video_paths, classes

    def __call__(self):
        video_paths, classes = self.get_files_and_class_names()

        pairs = list(zip(video_paths, classes))

        if self.training:
            random.shuffle(pairs)

        for path, name in pairs:
            video_frames = frames_from_video_file(path, self.n_frames) 
            label = self.class_ids_for_name[name] # Encode labels
            yield video_frames, label

# %% [markdown]
# #### Test out the FrameGenerator object before wrapping it as a TensorFlow Dataset object. Moreover, for the training dataset, ensure you enable training mode so that the data will be shuffled.

# %%
from pathlib import PosixPath

subset_paths = {}


main_path = "./datasets/base_dataset"
subset_paths['train'] = PosixPath(os.path.join(main_path, 'train'))
subset_paths['test'] = PosixPath(os.path.join(main_path, 'test'))
subset_paths['val'] = PosixPath(os.path.join(main_path, 'val'))

fg = FrameGenerator(subset_paths['train'], 120, training=True)

frames, label = next(fg())

print(f"Shape: {frames.shape}")
print(f"Label: {label}")
# Out:
# path datasets/base_dataset/train
# Shape: (120, 224, 224, 3)
# Label: 1

# %% [markdown]
# #### Finally, create a TensorFlow data input pipeline. This pipeline that you create from the generator object allows you to feed in data to your deep learning model. In this video pipeline, each element is a single set of frames and its associated label.

# %%
# Create the training set
output_signature = (tf.TensorSpec(shape = (None, None, None, 3), dtype = tf.float32),
                    tf.TensorSpec(shape = (), dtype = tf.int16))
train_ds = tf.data.Dataset.from_generator(FrameGenerator(subset_paths['train'], 60, training=True),
                                          output_signature = output_signature)
# Out:
# path datasets/base_dataset/train

# %%
for frames, labels in train_ds.take(10):
    print(labels)
# Out:
# tf.Tensor(0, shape=(), dtype=int16)
# tf.Tensor(1, shape=(), dtype=int16)
# tf.Tensor(0, shape=(), dtype=int16)
# tf.Tensor(0, shape=(), dtype=int16)
# tf.Tensor(1, shape=(), dtype=int16)
# tf.Tensor(1, shape=(), dtype=int16)
# tf.Tensor(0, shape=(), dtype=int16)
# tf.Tensor(1, shape=(), dtype=int16)
# tf.Tensor(1, shape=(), dtype=int16)
# tf.Tensor(1, shape=(), dtype=int16)

# %%
# Create the validation set
val_ds = tf.data.Dataset.from_generator(FrameGenerator(subset_paths['val'], 60),
                                        output_signature = output_signature)
# Out:
# path datasets/base_dataset/val

# %%
# Print the shapes of the data
train_frames, train_labels = next(iter(train_ds))
print(f'Shape of training set of frames: {train_frames.shape}')
print(f'Shape of training labels: {train_labels.shape}')

val_frames, val_labels = next(iter(val_ds))
print(f'Shape of validation set of frames: {val_frames.shape}')
print(f'Shape of validation labels: {val_labels.shape}')
# Out:
# Shape of training set of frames: (60, 224, 224, 3)
# Shape of training labels: ()
# Shape of validation set of frames: (60, 224, 224, 3)
# Shape of validation labels: ()

# %% [markdown]
# Configure the dataset for performance

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(500).prefetch(buffer_size = AUTOTUNE)
val_ds = val_ds.cache().shuffle(500).prefetch(buffer_size = AUTOTUNE)

# %%
train_ds = train_ds.batch(2)
val_ds = val_ds.batch(2)

train_frames, train_labels = next(iter(train_ds))
print(f'Shape of training set of frames: {train_frames.shape}')
print(f'Shape of training labels: {train_labels.shape}')

val_frames, val_labels = next(iter(val_ds))
print(f'Shape of validation set of frames: {val_frames.shape}')
print(f'Shape of validation labels: {val_labels.shape}')
# Out:
# 2023-11-09 23:40:02.449910: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:390] Filling up shuffle buffer (this may take a while): 20 of 1000
# 2023-11-09 23:40:09.437204: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:390] Filling up shuffle buffer (this may take a while): 39 of 1000
# 2023-11-09 23:40:22.119791: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:390] Filling up shuffle buffer (this may take a while): 57 of 1000
# 2023-11-09 23:40:29.493415: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:390] Filling up shuffle buffer (this may take a while): 70 of 1000
# 2023-11-09 23:40:39.840532: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:390] Filling up shuffle buffer (this may take a while): 90 of 1000
# 2023-11-09 23:40:42.754158: W tensorflow/core/framework/op_kernel.cc:1733] INVALID_ARGUMENT: ValueError: Attempt to convert a value (None) with an unsupported type (<class 'NoneType'>) to a Tensor.
# Traceback (most recent call last):
#
# ...

# %%
net = tf.keras.applications.EfficientNetB0(include_top = False)
net.trainable = False

model = tf.keras.Sequential([
    tf.keras.layers.Rescaling(scale=255),
    tf.keras.layers.TimeDistributed(net),
    tf.keras.layers.Dense(10),
    tf.keras.layers.GlobalAveragePooling3D()
])

model.compile(optimizer = 'adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),
              metrics=['accuracy'])

model.fit(train_ds, 
          epochs = 10,
          validation_data = val_ds,
          callbacks = tf.keras.callbacks.EarlyStopping(patience = 2, monitor = 'val_loss'))
